# %% [markdown]
# # Import Library

# %%
#import
import pandas as pd
import numpy as np

# Normalisasi
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# Import Library Linear dan Nonliner

# Linear
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import ridge_regression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

#Non Linear 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

#spliting ML
from sklearn.model_selection import train_test_split, KFold, cross_val_score

# Metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

#warning
import warnings
warnings.filterwarnings("ignore")

#
import pickle
import joblib

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("data_training_testing.csv", encoding="utf-8")
df
# Out:
#     Molecular_weight MW (g/mol)   pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 0                        192.12  2.79  -1.64   0.51                    63.24
# 1                        240.34  9.30   2.98  -2.80                   115.04
# 2                        252.34  6.80   0.40  -1.35                    82.25
# 3                        128.08  4.00  -1.47  -1.50                    37.30
# 4                        238.16  7.20  -0.47  -2.80                    75.27
# ..                          ...   ...    ...    ...                      ...
# 65                       180.16  3.50   1.80  -2.10                   182.00
# 66                       347.40  3.60   0.60  -3.10                    52.19
# 67                       249.29  8.40   0.35  -2.70                   117.78
# 68                       137.14  1.82  -0.70   0.01                   220.15
# 69                       214.25  2.80  -0.52  -2.40                    97.97
#
#     Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Electronegativity (eV)  \
# 0                 16.02     -7.116     -3.929                  5.5225
# 1                 19.16     -7.010     -3.358                  5.1840
# 2                 10.28     -6.967     -2.652                  4.8095
# 3                  5.34     -6.816     -1.070                  3.9430
# 4                 22.62     -6.720     -2.502                  4.6110
# ..                  ...        ...        ...                     ...
# 65                43.65     -5.693     -3.454                  4.5735
# 66                54.92     -4.838     -1.303                  3.0705
# 67                66.06     -4.905     -2.329                  3.6170
# 68                86.46     -4.855     -2.808                  3.8315
# 69                24.39     -4.165     -2.126                  3.1455
#
#       ΔN_Fe   IE EXP (%)
# 0   0.463602       83.78
# 1   0.497262       93.00
# 2   0.507648       97.70
# 3   0.532022       92.00
# 4   0.566382       95.00
# ..       ...         ...
# 65  1.083743       95.90
# 66  1.111598       93.09
# 67  1.313276       94.00
# 68  1.547875       94.70
# 69  1.890387       94.00
#
# [70 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Molecular_weight MW (g/mol)  70 non-null     float64
#  1   pKa                          70 non-null     float64
#  2   Log P                        70 non-null     float64
#  3   Log S                        70 non-null     float64
#  4   Polar Surface Area (Å2)      70 non-null     float64
#  5   Polarizability (Å3)          70 non-null     float64
#  6   HOMO (eV)                    70 non-null     float64
#  7   LUMO (eV)                    70 non-null     float64
#  8   Electronegativity (eV)       70 non-null     float64
#  9    ΔN_Fe                       70 non-null     float64
#  10  IE EXP (%)                   70 non-null     float64
# dtypes: float64(11)
# memory usage: 6.1 KB

# %% [markdown]
# # Preprocesing Data

# %%
df[['Molecular_weight MW (g/mol)', 'pKa', 'Log P','Log S','Polar Surface Area (Å2)','Polarizability (Å3)','HOMO (eV)','LUMO (eV)','Electronegativity (eV)',' ΔN_Fe ','IE EXP (%)']] = df[['Molecular_weight MW (g/mol)', 'pKa', 'Log P','Log S','Polar Surface Area (Å2)','Polarizability (Å3)','HOMO (eV)','LUMO (eV)','Electronegativity (eV)',' ΔN_Fe ','IE EXP (%)']].replace(',', '.', regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Molecular_weight MW (g/mol)  70 non-null     float64
#  1   pKa                          70 non-null     float64
#  2   Log P                        70 non-null     float64
#  3   Log S                        70 non-null     float64
#  4   Polar Surface Area (Å2)      70 non-null     float64
#  5   Polarizability (Å3)          70 non-null     float64
#  6   HOMO (eV)                    70 non-null     float64
#  7   LUMO (eV)                    70 non-null     float64
#  8   Electronegativity (eV)       70 non-null     float64
#  9    ΔN_Fe                       70 non-null     float64
#  10  IE EXP (%)                   70 non-null     float64
# dtypes: float64(11)
# memory usage: 6.1 KB

# %%
df_model = df[['Molecular_weight MW (g/mol)', 'pKa', 'Log P','Log S','Polar Surface Area (Å2)','Polarizability (Å3)','HOMO (eV)','LUMO (eV)','Electronegativity (eV)',' ΔN_Fe ','IE EXP (%)']] = df[['Molecular_weight MW (g/mol)', 'pKa', 'Log P','Log S','Polar Surface Area (Å2)','Polarizability (Å3)','HOMO (eV)','LUMO (eV)','Electronegativity (eV)',' ΔN_Fe ','IE EXP (%)']]

# %%
# df_model.head()
df_model
# Out:
#     Molecular_weight MW (g/mol)   pKa  Log P  Log S  Polar Surface Area (Å2)  \
# 0                        192.12  2.79  -1.64   0.51                    63.24
# 1                        240.34  9.30   2.98  -2.80                   115.04
# 2                        252.34  6.80   0.40  -1.35                    82.25
# 3                        128.08  4.00  -1.47  -1.50                    37.30
# 4                        238.16  7.20  -0.47  -2.80                    75.27
# ..                          ...   ...    ...    ...                      ...
# 65                       180.16  3.50   1.80  -2.10                   182.00
# 66                       347.40  3.60   0.60  -3.10                    52.19
# 67                       249.29  8.40   0.35  -2.70                   117.78
# 68                       137.14  1.82  -0.70   0.01                   220.15
# 69                       214.25  2.80  -0.52  -2.40                    97.97
#
#     Polarizability (Å3)  HOMO (eV)  LUMO (eV)  Electronegativity (eV)  \
# 0                 16.02     -7.116     -3.929                  5.5225
# 1                 19.16     -7.010     -3.358                  5.1840
# 2                 10.28     -6.967     -2.652                  4.8095
# 3                  5.34     -6.816     -1.070                  3.9430
# 4                 22.62     -6.720     -2.502                  4.6110
# ..                  ...        ...        ...                     ...
# 65                43.65     -5.693     -3.454                  4.5735
# 66                54.92     -4.838     -1.303                  3.0705
# 67                66.06     -4.905     -2.329                  3.6170
# 68                86.46     -4.855     -2.808                  3.8315
# 69                24.39     -4.165     -2.126                  3.1455
#
#       ΔN_Fe   IE EXP (%)
# 0   0.463602       83.78
# 1   0.497262       93.00
# 2   0.507648       97.70
# 3   0.532022       92.00
# 4   0.566382       95.00
# ..       ...         ...
# 65  1.083743       95.90
# 66  1.111598       93.09
# 67  1.313276       94.00
# 68  1.547875       94.70
# 69  1.890387       94.00
#
# [70 rows x 11 columns]

# %%
df_model.isna().sum()
# Out:
# Molecular_weight MW (g/mol)    0
# pKa                            0
# Log P                          0
# Log S                          0
# Polar Surface Area (Å2)        0
# Polarizability (Å3)            0
# HOMO (eV)                      0
# LUMO (eV)                      0
# Electronegativity (eV)         0
#  ΔN_Fe                         0
# IE EXP (%)                     0
# dtype: int64

# %%
df_model.dropna(inplace=True)

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Molecular_weight MW (g/mol)  70 non-null     float64
#  1   pKa                          70 non-null     float64
#  2   Log P                        70 non-null     float64
#  3   Log S                        70 non-null     float64
#  4   Polar Surface Area (Å2)      70 non-null     float64
#  5   Polarizability (Å3)          70 non-null     float64
#  6   HOMO (eV)                    70 non-null     float64
#  7   LUMO (eV)                    70 non-null     float64
#  8   Electronegativity (eV)       70 non-null     float64
#  9    ΔN_Fe                       70 non-null     float64
#  10  IE EXP (%)                   70 non-null     float64
# dtypes: float64(11)
# memory usage: 6.1 KB

# %%
df_model["Molecular_weight MW (g/mol)"] = df_model["Molecular_weight MW (g/mol)"].astype(float)
df_model["Log P"] = df_model["Log P"].astype(float)
df_model["Log S"] = df_model["Log S"].astype(float)
df_model["Polar Surface Area (Å2)"] = df_model["Polar Surface Area (Å2)"].astype(float)
df_model["Polarizability (Å3)"] = df_model["Polarizability (Å3)"].astype(float)

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Molecular_weight MW (g/mol)  70 non-null     float64
#  1   pKa                          70 non-null     float64
#  2   Log P                        70 non-null     float64
#  3   Log S                        70 non-null     float64
#  4   Polar Surface Area (Å2)      70 non-null     float64
#  5   Polarizability (Å3)          70 non-null     float64
#  6   HOMO (eV)                    70 non-null     float64
#  7   LUMO (eV)                    70 non-null     float64
#  8   Electronegativity (eV)       70 non-null     float64
#  9    ΔN_Fe                       70 non-null     float64
#  10  IE EXP (%)                   70 non-null     float64
# dtypes: float64(11)
# memory usage: 6.1 KB

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "SVR": SVR(),
    "KNeighbors Regressor": KNeighborsRegressor(), 
    "Random Forest Regressor":RandomForestRegressor(),
    "Lasso" : Lasso(),
    "Elastic Net" : ElasticNet()
}

# %%
# Variasi metode normalisasi
scalers = [RobustScaler(), StandardScaler(), MinMaxScaler(), "None"]

# Variasi pembagian data
test_sizes = [0.2, 0.3, 0.4]

# Loop untuk kombinasi
for model_name, model in models.items():
    for scaler in scalers:
        for test_size in test_sizes:
            # Splitting X dan y
            X = df_model[['Molecular_weight MW (g/mol)', 'pKa', 'Log P', 'Log S', 'Polar Surface Area (Å2)', 'Polarizability (Å3)', 'HOMO (eV)', 'LUMO (eV)', 'Electronegativity (eV)', ' ΔN_Fe ']]
            y = df_model['IE EXP (%)']

            # Bagi data
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

            # Normalisasi jika ada scaler
            if scaler != "None":
                X_train_scaled = scaler.fit_transform(X_train)
                X_test_scaled = scaler.transform(X_test)
                # y dinormalisasi
                y_train_scaled = scaler.fit_transform(y_train.values.reshape(-1, 1)).flatten()
                y_test_scaled = scaler.transform(y_test.values.reshape(-1, 1)).flatten()

            else:
                X_train_scaled = X_train
                X_test_scaled = X_test
                # y dinormalisasi
                y_train_scaled = y_train
                y_test_scaled = y_test

            # Latih model
            model.fit(X_train_scaled, y_train_scaled)

            # Prediksi dan evaluasi
            y_pred = model.predict(X_train_scaled)
            mse = mean_squared_error(y_train_scaled, y_pred)
            rmse = np.sqrt(mse)
            r2 = r2_score(y_train_scaled, y_pred)

            print(f"{model_name} | Scaler: {scaler} | Test Size: {test_size} | RMSE: {rmse} | R2 : {r2}")
            
            custom_path = f"{model_name}_{test_size}_{scaler}"
        
#             # Save the model using joblib
#             joblib.dump(model, f'{custom_path}.joblib')

#             # Save the model using pickle
#             with open(f'{custom_path}.pkl', 'wb') as model_file:
#                 pickle.dump(model, model_file)
# Out:
# Linear Regression | Scaler: RobustScaler() | Test Size: 0.2 | RMSE: 0.6765304905491497 | R2 : 0.09187172771081242
# Linear Regression | Scaler: RobustScaler() | Test Size: 0.3 | RMSE: 0.6860639766834986 | R2 : 0.08835698796737013
# Linear Regression | Scaler: RobustScaler() | Test Size: 0.4 | RMSE: 0.7409750491066751 | R2 : 0.1365450102634722
# Linear Regression | Scaler: StandardScaler() | Test Size: 0.2 | RMSE: 0.9529576445410296 | R2 : 0.09187172771081265
# Linear Regression | Scaler: StandardScaler() | Test Size: 0.3 | RMSE: 0.9547999853543306 | R2 : 0.08835698796737002
# Linear Regression | Scaler: StandardScaler() | Test Size: 0.4 | RMSE: 0.9292227879989425 | R2 : 0.13654501026347243
# Linear Regression | Scaler: MinMaxScaler() | Test Size: 0.2 | RMSE: 0.19661112685559243 | R2 : 0.09211011287332571
# Linear Regression | Scaler: MinMaxScaler() | Test Size: 0.3 | RMSE: 0.20739860425047768 | R2 : 0.07431180796725756
# Linear Regression | Scaler: MinMaxScaler() | Test Size: 0.4 | RMSE: 0.20572118775517628 | R2 : 0.1365450102634722
# Linear Regression | Scaler: None | Test Size: 0.2 | RMSE: 6.154736137770888 | R2 : 0.09187172771081253
# Linear Regression | Scaler: None | Test Size: 0.3 | RMSE: 6.4421407410580525 | R2 : 0.0883569879673698
# Linear Regression | Scaler: None | Test Size: 0.4 | RMSE: 6.439073176737016 | R2 : 0.1365450102634721
# Gradient Boosting Regressor | Scaler: RobustScaler() | Test Size: 0.2 | RMSE: 0
Scaler: RobustScaler() | Test Size: 0.2 | RMSE: 0.7099271351928607 | R2 : 0.0
# Lasso | Scaler: RobustScaler() | Test Size: 0.3 | RMSE: 0.7185420896596445 | R2 : 0.0
# Lasso | Scaler: RobustScaler() | Test Size: 0.4 | RMSE: 0.7974137727534061 | R2 : 0.0
# Lasso | Scaler: StandardScaler() | Test Size: 0.2 | RMSE: 1.0 | R2 : 0.0
# Lasso | Scaler: StandardScaler() | Test Size: 0.3 | RMSE: 1.0 | R2 : 0.0
# Lasso | Scaler: StandardScaler() | Test Size: 0.4 | RMSE: 1.0 | R2 : 0.0
# Lasso | Scaler: MinMaxScaler() | Test Size: 0.2 | RMSE: 0.20634383745741372 | R2 : 0.0
# Lasso | Scaler: MinMaxScaler() | Test Size: 0.3 | RMSE: 0.21556262689789335 | R2 : 0.0
# Lasso | Scaler: MinMaxScaler() | Test Size: 0.4 | RMSE: 0.2213905969721121 | R2 : 0.0
# Lasso | Scaler: None | Test Size: 0.2 | RMSE: 6.298500719313095 | R2 : 0.04895145509831833
# Lasso | Scaler: None | Test Size: 0.3 | RMSE: 6.575950261851943 | R2 : 0.05009225308209064
# Lasso | Scaler: None | Test Size: 0.4 | RMSE: 6.669267480605346 | R2 : 0.07370514078277757
# Elastic Net | Scaler: RobustScaler() | Test Size: 0.2 | RMSE: 0.7099271351928607 | R2 : 0.0
# Elastic Net | Scaler: RobustScaler() | Test Size: 0.3 | RMSE: 0.7185420896596445 | R2 : 0.0
# Elastic Net | Scaler: RobustScaler() | Test Size: 0.4 | RMSE: 0.7974137727534061 | R2 : 0.0
# Elastic Net | Scaler: StandardScaler() | Test Size: 0.2 | RMSE: 1.0 | R2 : 0.0
# Elastic Net | Scaler: StandardScaler() | Test Size: 0.3 | RMSE: 1.0 | R2 : 0.0
# Elastic Net | Scaler: StandardScaler() | Test Size: 0.4 | RMSE: 1.0 | R2 : 0.0
# Elastic Net | Scaler: MinMaxScaler() | Test Size: 0.2 | RMSE: 0.20634383745741372 | R2 : 0.0
# Elastic Net | Scaler: MinMaxScaler() | Test Size: 0.3 | RMSE: 0.21556262689789335 | R2 : 0.0
# Elastic Net | Scaler: MinMaxScaler() | Test Size: 0.4 | RMSE: 0.2213905969721121 | R2 : 0.0
# Elastic Net | Scaler: None | Test Size: 0.2 | RMSE: 6.261123456119874 | R2 : 0.060205598938653626
# Elastic Net | Scaler: None | Test Size: 0.3 | RMSE: 6.54156465064247 | R2 : 0.060000406102282966
# Elastic Net | Scaler: None | Test Size: 0.4 | RMSE: 6.642342531995187 | R2 : 0.08116925800021368

# %%
# Definisikan jumlah lipatan (folds) yang diinginkan
num_folds_list = [3, 5, 10]

# Variasi metode normalisasi
scalers = [RobustScaler(), StandardScaler(), MinMaxScaler(), "None"]

# Loop untuk kombinasi
for model_name, model in models.items():
    for scaler in scalers:
        for num_folds in num_folds_list:
            # Splitting X dan y
            X = df_model[['Molecular_weight MW (g/mol)', 'pKa', 'Log P', 'Log S', 'Polar Surface Area (Å2)', 'Polarizability (Å3)', 'HOMO (eV)', 'LUMO (eV)', 'Electronegativity (eV)', ' ΔN_Fe ']]
            y = df_model['IE EXP (%)']

#             # Normalisasi jika ada scaler
#             if scaler != "None":
#                 X_scaled = scaler.fit_transform(X)
#             else:
#                 X_scaled = X
                
            # Normalisasi scaler x dan y
            if scaler != "None":
                X_train_scaled = scaler.fit_transform(X_train)
                X_test_scaled = scaler.transform(X_test)
                y_train_scaled = scaler.transform(y_train.reshape(-1, 1)).flatten()
                y_test_scaled = scaler.transform(y_test.reshape(-1, 1)).flatten()
            else:
                X_train_scaled = X_train
                X_test_scaled = X_test
                y_train_scaled = y_train
                y_test_scaled = y_test

            # Latih model
            model.fit(X_scaled, y)

            kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)

            # Lakukan validasi silang
            mse_scores = cross_val_score(model, X_scaled, y, cv=kfold, scoring='neg_mean_squared_error')

            # Hitung rata-rata MSE dan ubah ke positif
            avg_mse = -np.mean(mse_scores)
            avg_rmse = np.sqrt(avg_mse)

            print(f"{model_name} | Scaler: {scaler} | Folds: {num_folds} | Average RMSE: {avg_rmse}")

#             # Simpan model menggunakan joblib
#             custom_path = f"{model_name}_{num_folds}_{scaler}"
#             joblib.dump(model, f'{custom_path}.joblib')

#             # Simpan model menggunakan pickle
#             with open(f'{custom_path}.pkl', 'wb') as model_file:
#                 pickle.dump(model, model_file)

# %% [markdown]
# # Pemisah
