# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("2022_drugs_perez_dataset_search engine.xlsx")
df
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Cell D160 is marked as a date but the serial value 9110947 is outside the limits for dates. The cell will be treated as an error.
#   for idx, row in parser.parse():
#         Common_name                                                Ref  \
# 0          Caffeine  https://pubchem.ncbi.nlm.nih.gov/compound/2519...
# 1     Acenocoumarol  https://pubchem.ncbi.nlm.nih.gov/compound/5467...
# 2     Acetaminophen     https://pubchem.ncbi.nlm.nih.gov/compound/1983
# 3    Acetazolamide               https://www.drugbank.ca/drugs/DB00819
# 4      Acetic acid               https://www.drugbank.ca/drugs/DB03166
# ..              ...                                                ...
# 246    Ethosuximide     https://pubchem.ncbi.nlm.nih.gov/compound/3291
# 247         Glycine      https://pubchem.ncbi.nlm.nih.gov/compound/750
# 248      Hexetidine     https://pubchem.ncbi.nlm.nih.gov/compound/3607
# ...

# %%
df.isna().sum()
# Out:
# Common_name                      0
# Ref                              1
# IUPAC_name                       2
# CAS_number                       2
# Formula                          1
# C                                1
# H                                1
# N                                1
# O                                1
# S                                1
# P                                1
# Canonical_smile                  1
# InchI                            4
# Molecular_weight MW (g/mol)      1
# pKa                              0
# Log P                            0
# Log S                            4
# Polar Surface Area (Å2)          0
# Polarizability (Å3)              1
# Hydrogen Acceptor Count          1
# Hydrogen Donor Count             1
# HOMO-1 (eV)                      1
# HOMO (eV)                        0
# LUMO (eV)                        0
# Ionization Energy I (eV)         1
# Electron Affinity A (eV)         1
# Electronegativity (eV)           1
# ...

# %%
df.drop(["IE ARX (%)"],axis=1,inplace=True)

# %%
df = df[['Molecular_weight MW (g/mol)', 'pKa', 'Log P', 'Log S', 'Polar Surface Area (Å2)', 'Polarizability (Å3)', 'HOMO (eV)', 'LUMO (eV)', 'Electronegativity (eV)', ' ΔN_Fe ']]

# %%
df
# Out:
#     Molecular_weight MW (g/mol)     pKa Log P Log S Polar Surface Area (Å2)  \
# 0                        194.19   14.00 -0.07 -0.97                   58.44
# 1                         353.3    4.70  1.98  -4.5                  109.42
# 2                        151.16    9.90  0.91  -1.6                   49.33
# 3                         222.3    8.80 -0.26 -2.36                  115.04
# 4                         60.05    4.80 -0.17  1.22                    37.3
# ..                          ...     ...   ...   ...                     ...
# 246                      141.17  141.17  0.38 -0.15                   46.17
# 247                       75.07   75.07 -3.21  0.87                   63.32
# 248                       339.6  339.60  5.74   4.8                    32.5
# 249                       442.4    2.21  -3.5  -2.6                  181.62
# 250                      250.28    6.50 -0.09 -3.51                   97.97
#
# ...

# %%
df.isna().sum()
# Out:
# Molecular_weight MW (g/mol)    1
# pKa                            0
# Log P                          0
# Log S                          4
# Polar Surface Area (Å2)        0
# Polarizability (Å3)            1
# HOMO (eV)                      0
# LUMO (eV)                      0
# Electronegativity (eV)         1
#  ΔN_Fe                         0
# dtype: int64

# %%
mean_data = df.mean()
df_new = df.fillna(mean_data)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18944\1555403499.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_data = df.mean()

# %%
df.isna().sum()
# Out:
# Molecular_weight MW (g/mol)    1
# pKa                            0
# Log P                          0
# Log S                          4
# Polar Surface Area (Å2)        0
# Polarizability (Å3)            1
# HOMO (eV)                      0
# LUMO (eV)                      0
# Electronegativity (eV)         0
#  ΔN_Fe                         0
# dtype: int64
